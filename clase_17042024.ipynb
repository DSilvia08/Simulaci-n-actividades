# %% [markdown]
# <a href="https://colab.research.google.com/github/DSilvia08/Simulaci-n-actividades/blob/main/clase_17042024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
def incisob(n):
 lista=[]
 for i in range(n):
  u=rnd.random()
  if 1<=u<1/4:
   x=(5/4)-((25/16 -2*u)**(1/2))
   lista.append(x)
  else:
   x=4*u
   lista.append(x)
 return lista

# %%
D=incisob(10000)

# %%
def cdf(D):
 n=len(D)
 x=np.sort(D)
 y=np.arange(0,n)/n
 return x,y

# %%
x,y=cdf(D)

# %%
plt.hist(D)
# Out:
# (array([1030.,  948.,  990.,  962., 1037., 1004.,  949., 1049.,  970.,
#         1061.]),
#  array([1.57847329e-04, 4.00134636e-01, 8.00111425e-01, 1.20008821e+00,
#         1.60006500e+00, 2.00004179e+00, 2.40001858e+00, 2.79999537e+00,
#         3.19997216e+00, 3.59994895e+00, 3.99992574e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(D)

# %%
plt.step(x,y)

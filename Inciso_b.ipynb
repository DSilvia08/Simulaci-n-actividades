# %% [markdown]
# <a href="https://colab.research.google.com/github/DSilvia08/Simulaci-n-actividades/blob/main/Inciso_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
R=0
print("Método de Congruencia")
m=int(input("Ingrese un valor para m: "))
x_n=int(input("Ingrese un número menor que m y mayor que 0: "))
a=int(input("Ingrese un valor para a: "))
c=int(input("Ingrese un valor para c: "))

print("{:<8} {:<10} {:<10} {:<8} {:<15}".format("n", "x_n", "ax_n+c", "ax_n+c % m", "x_n/m"))

for n in range(0,129):
  P=(a*x_n) + c
  M=P%m
  N=x_n/m
  d=[[n, x_n, P, M, N]]
  print("{:<8} {:<10} {:<10} {:<8} {:<15}".format(n, x_n, P, M, N))
  x_n=M
# Out:
# Método de Congruencia
# Ingrese un valor para m: 128
# Ingrese un número menor que m y mayor que 0: 7
# Ingrese un valor para a: 13
# Ingrese un valor para c: 9
# n        x_n        ax_n+c     ax_n+c % m x_n/m
# 0        7          100        100      0.0546875
# 1        100        1309       29       0.78125
# 2        29         386        2        0.2265625
# 3        2          35         35       0.015625
# 4        35         464        80       0.2734375
# 5        80         1049       25       0.625
# 6        25         334        78       0.1953125
# 7        78         1023       127      0.609375
# 8        127        1660       124      0.9921875
# 9        124        1621       85       0.96875
# 10       85         1114       90       0.6640625
# 11       90         1179       27       0.703125
# 12       27         360        104      0.2109375
# 13       104        1361       81       0.8125
# 14       81         1062       38       0.6328125
# 15       38         503        119      0.296875
# 16       119        1556       20       0.9296875
# 17       20         269        13       0.15625
# 18       13         178        50       0.1015625
# 19       50         659        19       0.390625
# 20       19         256        0        0.1484375
# 21       0          9          9        0.0
# 22       9          126        126      0.0703125
# 23       126        1647       111      0.984375
# 24       111        1452       44       0.8671875
# 25       44         581        69       0.34375
# 26       69         906        10       0.5390625
# 27       10         139        11       0.078125
# 28       11         152        24       0.0859375
# 29       24         321        65       0.1875
# 30       65         854        86       0.5078125
# 31       86         1127       103      0.671875
# 32       103        1348       68       0.8046875
# 33       68         893        125      0.53125
# 34       125        1634       98       0.9765625
# 35       98         1283       3        0.765625
# 36       3          48         48       0.0234375
# 37       48         633        121      0.375
# 38       121        1582       46       0.9453125
# 39       46         607        95       0.359375
# 40       95         1244       92       0.7421875
# 41       92         1205       53       0.71875
# 42       53         698        58       0.4140625
# 43       58         763        123      0.453125
# 44       123        1608       72       0.9609375
# 45       72         945        49       0.5625
# 46       49         646        6        0.3828125
# 47       6          87         87       0.046875
# 48       87         1140       116      0.6796875
# 49       116        1517       109      0.90625
# 50       109        1426       18       0.8515625
# 51       18         243        115      0.140625
# 52       115        1504       96       0.8984375
# 53       96         1257       105      0.75
# 54       105        1374       94       0.8203125
# 55       94         1231       79       0.734375
# 56       79         1036       12       0.6171875
# 57       12         165        37       0.09375
# 58       37         490        106      0.2890625
# 59       106        1387       107      0.828125
# 60       107        1400       120      0.8359375
# 61       120        1569       33       0.9375
# 62       33         438        54       0.2578125
# 63       54         711        71       0.421875
# 64       71         932        36       0.5546875
# 65       36         477        93       0.28125
# 66       93         1218       66       0.7265625
# 67       66         867        99       0.515625
# 68       99         1296       16       0.7734375
# 69       16         217        89       0.125
# 70       89         1166       14       0.6953125
# 71       14         191        63       0.109375
# 72       63         828        60       0.4921875
# 73       60         789        21       0.46875
# 74       21         282        26       0.1640625
# 75       26         347        91       0.203125
# 76       91         1192       40       0.7109375
# 77       40         529        17       0.3125
# 78       17         230        102      0.1328125
# 79       102        1335       55       0.796875
# 80       55         724        84       0.4296875
# 81       84         1101       77       0.65625
# 82       77         1010       114      0.6015625
# 83       114        1491       83       0.890625
# 84       83         1088       64       0.6484375
# 85       64         841        73       0.5
# 86       73         958        62       0.5703125
# 87       62         815        47       0.484375
# 88       47         620        108      0.3671875
# 89       108        1413       5        0.84375
# 90       5          74         74       0.0390625
# 91       74         971        75       0.578125
# 92       75         984        88       0.5859375
# 93       88         1153       1        0.6875
# 94       1          22         22       0.0078125
# 95       22         295        39       0.171875
# 96       39         516        4        0.3046875
# 97       4          61         61       0.03125
# 98       61         802        34       0.4765625
# 99       34         451        67       0.265625
# 100      67         880        112      0.5234375
# 101      112        1465       57       0.875
# 102      57         750        110      0.4453125
# 103      110        1439       31       0.859375
# 104      31         412        28       0.2421875
# 105      28         373        117      0.21875
# 106      117        1530       122      0.9140625
# 107      122        1595       59       0.953125
# 108      59         776        8        0.4609375
# 109      8          113        113      0.0625
# 110      113        1478       70       0.8828125
# 111      70         919        23       0.546875
# 112      23         308        52       0.1796875
# 113      52         685        45       0.40625
# 114      45         594        82       0.3515625
# 115      82         1075       51       0.640625
# 116      51         672        32       0.3984375
# 117      32         425        41       0.25
# 118      41         542        30       0.3203125
# 119      30         399        15       0.234375
# 120      15         204        76       0.1171875
# 121      76         997        101      0.59375
# 122      101        1322       42       0.7890625
# 123      42         555        43       0.328125
# 124      43         568        56       0.3359375
# 125      56         737        97       0.4375
# 126      97         1270       118      0.7578125
# 127      118        1543       7        0.921875
# 128      7          100        100      0.0546875

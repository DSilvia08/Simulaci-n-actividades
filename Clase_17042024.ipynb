# %% [markdown]
# <a href="https://colab.research.google.com/github/DSilvia08/Simulaci-n-actividades/blob/main/Clase_17042024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
def incisob(n):
 lista=[]
 for i in range(n):
  u=rnd.random()
  if 0<=u<3/4:
   x=(5/4)-((25/16 -2*u)**(1/2))
   lista.append(x)
  else:
   x=(4*u)-2
   lista.append(x)
 return lista

# %%
D=incisob(10000)

# %%
def cdf(D):
 n=len(D)
 x=np.sort(D)
 y=np.arange(0,n)/n
 return x,y

# %%
x,y=cdf(D)

# %%
plt.hist(D)
# Out:
# (array([2360., 1884., 1442., 1099.,  723.,  497.,  476.,  531.,  477.,
#          511.]),
#  array([1.55955020e-04, 2.00121914e-01, 4.00087872e-01, 6.00053831e-01,
#         8.00019790e-01, 9.99985748e-01, 1.19995171e+00, 1.39991767e+00,
#         1.59988362e+00, 1.79984958e+00, 1.99981554e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(D)

# %%
plt.step(x,y)
